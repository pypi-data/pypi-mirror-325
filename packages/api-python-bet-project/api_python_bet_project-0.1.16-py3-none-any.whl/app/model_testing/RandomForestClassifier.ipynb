# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import FunctionTransformer

# %% [markdown]
# # Model testing

# %%
# Leer los datos desde el archivo CSV
df = pd.read_csv('final_dataset.csv')

# Seleccionar las características y la variable objetivo
X = df[['home_team_name', 'away_team_name', 'home_team_rank', 'away_team_rank', 'day_of_week', 'home_team_points', 'away_team_points']]
y = df['result']

# Crear un pipeline de preprocesamiento
preprocessor = ColumnTransformer(
    transformers=[
        ('team', OneHotEncoder(handle_unknown='ignore', sparse_output=False), ['home_team_name', 'away_team_name']),
        ('rank', FunctionTransformer(lambda x: np.column_stack([
            np.cos(2 * np.pi * x / 20),
            np.sin(2 * np.pi * x / 20)
        ]), validate=True), ['home_team_rank', 'away_team_rank']),
        ('day', FunctionTransformer(lambda x: np.column_stack([
            np.cos(2 * np.pi * x / 7),
            np.sin(2 * np.pi * x / 7)
        ]), validate=True), ['day_of_week']),
        ('num', SimpleImputer(strategy='mean'), ['home_team_points', 'away_team_points'])
    ]
)

# Crear el pipeline completo con el modelo Random Forest
model_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('scaler', StandardScaler()),
        ('classifier', RandomForestClassifier(random_state=42))
    ]
)

# Inicializar TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)

# Listas para almacenar los resultados de cada split
scores_train = []
scores_test = []

# Inicializar la variable para almacenar el modelo ajustado del último split
last_model = None

# Iterar sobre los splits para entrenar el modelo
for split, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Entrenar el modelo con el conjunto de entrenamiento
    model_pipeline.fit(X_train, y_train)
    
    # Guardar el modelo del último split
    if split == tscv.get_n_splits():
        last_model = model_pipeline.named_steps['classifier']
    
    # Predecir en el conjunto de entrenamiento y prueba
    y_train_pred = model_pipeline.predict(X_train)
    y_test_pred = model_pipeline.predict(X_test)
    
    # Calcular la exactitud en entrenamiento y prueba
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    
    # Almacenar los resultados
    scores_train.append(train_accuracy)
    scores_test.append(test_accuracy)

    # Mostrar los resultados del último split
    if split == tscv.get_n_splits():
        print(f"Last Split Train Accuracy: {train_accuracy:.4f}")
        print(f"Last Split Test Accuracy: {test_accuracy:.4f}")

# Mostrar los resultados promedios
print(f"Average Train Accuracy: {sum(scores_train)/len(scores_train):.4f}")
print(f"Average Test Accuracy: {sum(scores_test)/len(scores_test):.4f}")
# Out:
# Last Split Train Accuracy: 1.0000
# Last Split Test Accuracy: 0.4783
# Average Train Accuracy: 1.0000
# Average Test Accuracy: 0.4704

# %%
# Obtener la importancia de las características después de haber ajustado el modelo
importances = last_model.feature_importances_

# Obtener las columnas procesadas del preprocesador
preprocessor = model_pipeline.named_steps['preprocessor']

# Verificar las columnas que el preprocesador maneja
print("Features processed by the preprocessor:")
print(preprocessor.transformers_)

# Obtener las columnas one-hot de las dos columnas categóricas
one_hot_columns = preprocessor.transformers_[0][1].get_feature_names_out()

# Agregar las otras columnas numéricas
numerical_columns = ['home_team_rank', 'away_team_rank', 'day_of_week', 'home_team_points', 'away_team_points']
feature_names = np.concatenate([one_hot_columns, numerical_columns])

# Verificar las longitudes
print(f"Feature names length: {len(feature_names)}")
print(f"Importances length: {len(importances)}")

# Si las longitudes coinciden, proceder con la creación del DataFrame
if len(feature_names) == len(importances):
    # Crear un DataFrame para mostrar la importancia
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    }).sort_values(by='Importance', ascending=False)

    # Mostrar la importancia de las características
    print(importance_df)
else:
    print("Error: La longitud de los nombres de las características no coincide con la longitud de los valores de importancia.")

# Verificar la longitud de los arrays
print("Feature names:")
print(feature_names)
print("Importances:")
print(importances)
# Out:
# Features processed by the preprocessor:
# [('team', OneHotEncoder(handle_unknown='ignore', sparse_output=False), ['team_pair']), ('rank', FunctionTransformer(func=<function <lambda> at 0x00000165E940E0C0>,
#                     validate=True), ['home_team_rank', 'away_team_rank']), ('day', FunctionTransformer(func=<function <lambda> at 0x00000165E940CA40>,
#                     validate=True), ['day_of_week']), ('remainder', 'drop', [1])]
# Feature names length: 305
# Importances length: 306
# Error: La longitud de los nombres de las características no coincide con la longitud de los valores de importancia.
# Feature names:
# ['team_pair_Alaves_Almeria' 'team_pair_Alaves_Athletic_Club'
#  'team_pair_Alaves_Atletico_Madrid' 'team_pair_Alaves_Barcelona'
#  'team_pair_Alaves_Cadiz' 'team_pair_Alaves_Celta_Vigo'
#  'team_pair_Alaves_Eibar' 'team_pair_Alaves_Elche'
#  'team_pair_Alaves_Espanyol' 'team_pair_Alaves_Getafe'
#  'team_pair_Alaves_Granada' 'team_pair_Alaves_Huesca'
#  'team_pair_Alaves_Levante' 'team_pair_Alaves_Mallorca'
#  'team_pair_Alaves_Osasuna' 'team_pair_Alaves_Rayo_Vallecano'
#  'team_pair_Alaves_Real_Betis' 'team_pair_Alaves_Real_Madrid'
#  'team_pair_Alaves_Real_Sociedad' 'team_pair_Alaves_Sevilla'
#  'team_pair_Alaves_Valencia' 'team_pair_Alaves_Valladolid'
#  'team_pair_Alaves_Villarreal' 'team_pair_Almeria_Athletic_Club'
#  'team_pair_Almeria_Atletico_Madrid' 'team_pair_Almeria_Barcelona'
#  'team_pair_Almeria_Cadiz' 'team_pair_Almeria_Celta_Vigo'
#  'team_pair_Almeria_Elche' 'team_pair_Almeria_Espanyol'
#  'team_pair_Almeria_Getafe' 'team_pair_Almeria_Girona'
#  'team_pair_Almeria_Granada' 'team_pair_Almeria_Las_Palmas'
#  'team_pair_Almeria_Mallorca' 'team_pair_Almeria_Osasuna'
#  'team_pair_Almeria_Rayo_Vallecano' 'team_pair_Almeria_Real_Betis'
#  'team_pair_Almeria_Real_Madrid' 'team_pair_Almeria_Real_Sociedad'
#  'team_pair_Almeria_Sevilla' 'team_pair_Almeria_Valencia'
#  'team_pair_Almeria_Valladolid' 'team_pair_Almeria_Villarreal'
#  'team_pair_Athletic_Club_Atletico_Madrid'
#  'team_pair_Athletic_Club_Barcelona' 'team_pair_Athletic_Club_Cadiz'
#  'team_pair_Athletic_Club_Celta_Vigo' 'team_pair_Athletic_Club_Eibar'
#  'team_pair_Athletic_Club_Elche' 'team_pair_Athletic_Club_Espanyol'
#  'team_pair_Athletic_Club_Getafe' 'team_pair_Athletic_Club_Girona'
#  'team_pair_Athletic_Club_Granada' 'team_pair_Athletic_Club_Huesca'
#  'team_pair_Athletic_Club_Levante' 'team_pair_Athletic_Club_Mallorca'
#  'team_pair_Athletic_Club_Osasuna'
#  'team_pair_Athletic_Club_Rayo_Vallecano'
#  'team_pair_Athletic_Club_Real_Betis'
#  'team_pair_Athletic_Club_Real_Madrid'
#  'team_pair_Athletic_Club_Real_Sociedad' 'team_pair_Athletic_Club_Sevilla'
#  'team_pair_Athletic_Club_Valencia' 'team_pair_Athletic_Club_Valladolid'
#  'team_pair_Athletic_Club_Villarreal'
#  'team_pair_Atletico_Madrid_Barcelona' 'team_pair_Atletico_Madrid_Cadiz'
#  'team_pair_Atletico_Madrid_Celta_Vigo' 'team_pair_Atletico_Madrid_Eibar'
#  'team_pair_Atletico_Madrid_Elche' 'team_pair_Atletico_Madrid_Espanyol'
#  'team_pair_Atletico_Madrid_Getafe' 'team_pair_Atletico_Madrid_Girona'
#  'team_pair_Atletico_Madrid_Granada' 'team_pair_Atletico_Madrid_Huesca'
#  'team_pair_Atletico_Madrid_Las_Palmas'
#  'team_pair_Atletico_Madrid_Levante' 'team_pair_Atletico_Madrid_Mallorca'
#  'team_pair_Atletico_Madrid_Osasuna'
#  'team_pair_Atletico_Madrid_Rayo_Vallecano'
#  'team_pair_Atletico_Madrid_Real_Betis'
#  'team_pair_Atletico_Madrid_Real_Madrid'
#  'team_pair_Atletico_Madrid_Real_Sociedad'
#  'team_pair_Atletico_Madrid_Sevilla' 'team_pair_Atletico_Madrid_Valencia'
#  'team_pair_Atletico_Madrid_Valladolid'
#  'team_pair_Atletico_Madrid_Villarreal' 'team_pair_Barcelona_Cadiz'
#  'team_pair_Barcelona_Celta_Vigo' 'team_pair_Barcelona_Eibar'
#  'team_pair_Barcelona_Elche' 'team_pair_Barcelona_Espanyol'
#  'team_pair_Barcelona_Getafe' 'team_pair_Barcelona_Girona'
#  'team_pair_Barcelona_Granada' 'team_pair_Barcelona_Huesca'
#  'team_pair_Barcelona_Levante' 'team_pair_Barcelona_Mallorca'
#  'team_pair_Barcelona_Osasuna' 'team_pair_Barcelona_Rayo_Vallecano'
#  'team_pair_Barcelona_Real_Betis' 'team_pair_Barcelona_Real_Madrid'
#  'team_pair_Barcelona_Real_Sociedad' 'team_pair_Barcelona_Sevilla'
#  'team_pair_Barcelona_Valencia' 'team_pair_Barcelona_Valladolid'
#  'team_pair_Barcelona_Villarreal' 'team_pair_Cadiz_Celta_Vigo'
#  'team_pair_Cadiz_Eibar' 'team_pair_Cadiz_Elche'
#  'team_pair_Cadiz_Espanyol' 'team_pair_Cadiz_Getafe'
#  'team_pair_Cadiz_Girona' 'team_pair_Cadiz_Granada'
#  'team_pair_Cadiz_Huesca' 'team_pair_Cadiz_Levante'
#  'team_pair_Cadiz_Mallorca' 'team_pair_Cadiz_Osasuna'
#  'team_pair_Cadiz_Rayo_Vallecano' 'team_pair_Cadiz_Real_Betis'
#  'team_pair_Cadiz_Real_Madrid' 'team_pair_Cadiz_Real_Sociedad'
#  'team_pair_Cadiz_Sevilla' 'team_pair_Cadiz_Valencia'
#  'team_pair_Cadiz_Valladolid' 'team_pair_Cadiz_Villarreal'
#  'team_pair_Celta_Vigo_Eibar' 'team_pair_Celta_Vigo_Elche'
#  'team_pair_Celta_Vigo_Espanyol' 'team_pair_Celta_Vigo_Getafe'
#  'team_pair_Celta_Vigo_Girona' 'team_pair_Celta_Vigo_Granada'
#  'team_pair_Celta_Vigo_Huesca' 'team_pair_Celta_Vigo_Las_Palmas'
#  'team_pair_Celta_Vigo_Levante' 'team_pair_Celta_Vigo_Mallorca'
#  'team_pair_Celta_Vigo_Osasuna' 'team_pair_Celta_Vigo_Rayo_Vallecano'
#  'team_pair_Celta_Vigo_Real_Betis' 'team_pair_Celta_Vigo_Real_Madrid'
#  'team_pair_Celta_Vigo_Real_Sociedad' 'team_pair_Celta_Vigo_Sevilla'
#  'team_pair_Celta_Vigo_Valencia' 'team_pair_Celta_Vigo_Valladolid'
#  'team_pair_Celta_Vigo_Villarreal' 'team_pair_Eibar_Elche'
#  'team_pair_Eibar_Getafe' 'team_pair_Eibar_Granada'
#  'team_pair_Eibar_Huesca' 'team_pair_Eibar_Levante'
#  'team_pair_Eibar_Osasuna' 'team_pair_Eibar_Real_Betis'
#  'team_pair_Eibar_Real_Madrid' 'team_pair_Eibar_Real_Sociedad'
#  'team_pair_Eibar_Sevilla' 'team_pair_Eibar_Valencia'
#  'team_pair_Eibar_Valladolid' 'team_pair_Eibar_Villarreal'
#  'team_pair_Elche_Espanyol' 'team_pair_Elche_Getafe'
#  'team_pair_Elche_Girona' 'team_pair_Elche_Granada'
#  'team_pair_Elche_Huesca' 'team_pair_Elche_Levante'
#  'team_pair_Elche_Mallorca' 'team_pair_Elche_Osasuna'
#  'team_pair_Elche_Rayo_Vallecano' 'team_pair_Elche_Real_Betis'
#  'team_pair_Elche_Real_Madrid' 'team_pair_Elche_Real_Sociedad'
#  'team_pair_Elche_Sevilla' 'team_pair_Elche_Valencia'
#  'team_pair_Elche_Valladolid' 'team_pair_Elche_Villarreal'
#  'team_pair_Espanyol_Getafe' 'team_pair_Espanyol_Girona'
#  'team_pair_Espanyol_Granada' 'team_pair_Espanyol_Levante'
#  'team_pair_Espanyol_Mallorca' 'team_pair_Espanyol_Osasuna'
#  'team_pair_Espanyol_Rayo_Vallecano' 'team_pair_Espanyol_Real_Betis'
#  'team_pair_Espanyol_Real_Madrid' 'team_pair_Espanyol_Real_Sociedad'
#  'team_pair_Espanyol_Sevilla' 'team_pair_Espanyol_Valencia'
#  'team_pair_Espanyol_Valladolid' 'team_pair_Espanyol_Villarreal'
#  'team_pair_Getafe_Girona' 'team_pair_Getafe_Granada'
#  'team_pair_Getafe_Huesca' 'team_pair_Getafe_Levante'
#  'team_pair_Getafe_Mallorca' 'team_pair_Getafe_Osasuna'
#  'team_pair_Getafe_Rayo_Vallecano' 'team_pair_Getafe_Real_Betis'
#  'team_pair_Getafe_Real_Madrid' 'team_pair_Getafe_Real_Sociedad'
#  'team_pair_Getafe_Sevilla' 'team_pair_Getafe_Valencia'
#  'team_pair_Getafe_Valladolid' 'team_pair_Getafe_Villarreal'
#  'team_pair_Girona_Granada' 'team_pair_Girona_Las_Palmas'
#  'team_pair_Girona_Mallorca' 'team_pair_Girona_Osasuna'
#  'team_pair_Girona_Rayo_Vallecano' 'team_pair_Girona_Real_Betis'
#  'team_pair_Girona_Real_Madrid' 'team_pair_Girona_Real_Sociedad'
#  'team_pair_Girona_Sevilla' 'team_pair_Girona_Valencia'
#  'team_pair_Girona_Valladolid' 'team_pair_Girona_Villarreal'
#  'team_pair_Granada_Huesca' 'team_pair_Granada_Las_Palmas'
#  'team_pair_Granada_Levante' 'team_pair_Granada_Mallorca'
#  'team_pair_Granada_Osasuna' 'team_pair_Granada_Rayo_Vallecano'
#  'team_pair_Granada_Real_Betis' 'team_pair_Granada_Real_Madrid'
#  'team_pair_Granada_Real_Sociedad' 'team_pair_Granada_Sevilla'
#  'team_pair_Granada_Valencia' 'team_pair_Granada_Valladolid'
#  'team_pair_Granada_Villarreal' 'team_pair_Huesca_Levante'
#  'team_pair_Huesca_Osasuna' 'team_pair_Huesca_Real_Betis'
#  'team_pair_Huesca_Real_Madrid' 'team_pair_Huesca_Real_Sociedad'
#  'team_pair_Huesca_Sevilla' 'team_pair_Huesca_Valencia'
#  'team_pair_Huesca_Valladolid' 'team_pair_Huesca_Villarreal'
#  'team_pair_Las_Palmas_Mallorca' 'team_pair_Las_Palmas_Osasuna'
#  'team_pair_Las_Palmas_Rayo_Vallecano' 'team_pair_Las_Palmas_Real_Madrid'
#  'team_pair_Las_Palmas_Real_Sociedad' 'team_pair_Las_Palmas_Sevilla'
#  'team_pair_Las_Palmas_Valencia' 'team_pair_Las_Palmas_Villarreal'
#  'team_pair_Levante_Mallorca' 'team_pair_Levante_Osasuna'
#  'team_pair_Levante_Rayo_Vallecano' 'team_pair_Levante_Real_Betis'
#  'team_pair_Levante_Real_Madrid' 'team_pair_Levante_Real_Sociedad'
#  'team_pair_Levante_Sevilla' 'team_pair_Levante_Valencia'
#  'team_pair_Levante_Valladolid' 'team_pair_Levante_Villarreal'
#  'team_pair_Mallorca_Osasuna' 'team_pair_Mallorca_Rayo_Vallecano'
#  'team_pair_Mallorca_Real_Betis' 'team_pair_Mallorca_Real_Madrid'
#  'team_pair_Mallorca_Real_Sociedad' 'team_pair_Mallorca_Sevilla'
#  'team_pair_Mallorca_Valencia' 'team_pair_Mallorca_Valladolid'
#  'team_pair_Mallorca_Villarreal' 'team_pair_Osasuna_Rayo_Vallecano'
#  'team_pair_Osasuna_Real_Betis' 'team_pair_Osasuna_Real_Madrid'
#  'team_pair_Osasuna_Real_Sociedad' 'team_pair_Osasuna_Sevilla'
#  'team_pair_Osasuna_Valencia' 'team_pair_Osasuna_Valladolid'
#  'team_pair_Osasuna_Villarreal' 'team_pair_Rayo_Vallecano_Real_Betis'
#  'team_pair_Rayo_Vallecano_Real_Madrid'
#  'team_pair_Rayo_Vallecano_Real_Sociedad'
#  'team_pair_Rayo_Vallecano_Sevilla' 'team_pair_Rayo_Vallecano_Valencia'
#  'team_pair_Rayo_Vallecano_Valladolid'
#  'team_pair_Rayo_Vallecano_Villarreal' 'team_pair_Real_Betis_Real_Madrid'
#  'team_pair_Real_Betis_Real_Sociedad' 'team_pair_Real_Betis_Sevilla'
#  'team_pair_Real_Betis_Valencia' 'team_pair_Real_Betis_Valladolid'
#  'team_pair_Real_Betis_Villarreal' 'team_pair_Real_Madrid_Real_Sociedad'
#  'team_pair_Real_Madrid_Sevilla' 'team_pair_Real_Madrid_Valencia'
#  'team_pair_Real_Madrid_Valladolid' 'team_pair_Real_Madrid_Villarreal'
