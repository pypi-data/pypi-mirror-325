# %%
from datasets import load_dataset

dataset = load_dataset("timm/oxford-iiit-pet")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'image_id', 'label_cat_dog'],
#         num_rows: 3680
#     })
#     test: Dataset({
#         features: ['image', 'label', 'image_id', 'label_cat_dog'],
#         num_rows: 3669
#     })
# })

# %% [markdown]
# ## Save the dataset locally

# %%
from pathlib import Path
from loguru import logger
from datasets import DatasetDict
from PIL import Image

SAVE_DIR = Path("data/oxford-iiit-pet")
NUM_PROC = 8  
CLASS_NAMES = dataset['train'].features['label'].names

def save_image(example, idx):
    """Save a dataset image to disk with error handling and add label name.
    
    Args:
        example (dict): Dataset example containing 'image' and 'label'
        idx (int): Index of the example
        
    Returns:
        dict: Dictionary containing the saved filepath and label_name
    """
    try:
        image = example['image']
        label_id = example.get('label')  # Get label if it exists 
        image_id = example.get('image_id')
        
        # Convert RGBA to RGB if necessary
        if image.mode == 'RGBA':
            # Create a white background
            background = Image.new('RGB', image.size, (255, 255, 255))
            # Paste the image using alpha channel as mask
            background.paste(image, mask=image.split()[3])
            image = background
        
        # Get label name if label exists
        label_name = CLASS_NAMES[label_id] if label_id is not None else None
        
        # Create directory structure
        label_dir = SAVE_DIR / str(label_id if label_id is not None else 'unlabeled')
        label_dir.mkdir(parents=True, exist_ok=True)
        
        # Create filename with label subdirectory
        filepath = label_dir / f"{image_id}.jpg"
        
        # Save with quality optimization
        image.save(filepath, "JPEG", quality=95, optimize=True)
        
        return {
            "filepath": str(filepath),
            "label_name": label_name
        }
    
    except Exception as e:
        logger.error(f"Error saving image {idx}: {str(e)}")
        return {
            "filepath": None,
            "label_name": None
        }

active_learning_dataset = DatasetDict()

active_learning_dataset['evaluation'] = dataset['test'].map(
    save_image,
    with_indices=True,
    num_proc=NUM_PROC,
    desc="Saving evaluation images",
    remove_columns="label"
)

active_learning_dataset['unlabeled'] = dataset['train'].map(
    save_image,
    with_indices=True,
    num_proc=NUM_PROC,
    desc="Saving unlabeled images",
    remove_columns="label"
)
# Out:
# Parameter 'function'=<function save_image at 0x7d1deba9a980> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Saving evaluation images (num_proc=8):   0%|          | 0/3669 [00:00<?, ? examples/s]
# Saving unlabeled images (num_proc=8):   0%|          | 0/3680 [00:00<?, ? examples/s]

# %%
active_learning_dataset
# Out:
# DatasetDict({
#     evaluation: Dataset({
#         features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#         num_rows: 3669
#     })
#     unlabeled: Dataset({
#         features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#         num_rows: 3680
#     })
# })

# %% [markdown]
# ## Make Initial Samples

# %%
import numpy as np

unique_labels = active_learning_dataset["unlabeled"].unique("label_name")
samples = []
n_samples_per_class = 10

for label in unique_labels:
    label_indices = np.where(np.array(active_learning_dataset["unlabeled"]["label_name"]) == label)[0]
    # Sample 10 random indices without replacement
    random_indices = np.random.choice(
        label_indices, size=n_samples_per_class, replace=False
    )
    samples.extend(random_indices)

initial_samples = active_learning_dataset["unlabeled"].select(samples)

# Verify the result (should show 100 rows total, 10 per class)
print(f"Total samples: {len(initial_samples)}")
print("\nSamples per class:")
print(initial_samples.select_columns(["label_name"]).to_pandas().value_counts())
# Out:
# Total samples: 370
#
# Samples per class:
# label_name
# abyssinian                    10
# american_bulldog              10
# american_pit_bull_terrier     10
# basset_hound                  10
# beagle                        10
# bengal                        10
# birman                        10
# bombay                        10
# boxer                         10
# british_shorthair             10
# chihuahua                     10
# egyptian_mau                  10
# english_cocker_spaniel        10
# english_setter                10
# german_shorthaired            10
# great_pyrenees                10
# havanese                      10
# japanese_chin                 10
# keeshond                      10
# leonberger                    10
# maine_coon                    10
# miniature_pinscher            10
# newfoundland                  10
# persian                       10
# pomeranian                    10
# pug                           10
# ragdoll                       10
# russian_blue                  10
# saint_bernard                 10
# samoyed                       10
# scottish_terrier              10
# shiba_inu                     10
# siamese                       10
# sphynx                        10
# staffordshire_bull_terrier    10
# wheaten_terrier               10
# yorkshire_terrier             10
# Name: count, dtype: int64

# %%
initial_samples
# Out:
# Dataset({
#     features: ['image', 'image_id', 'label_cat_dog', 'filepath', 'label_name'],
#     num_rows: 370
# })

# %%
initial_samples[1]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=403x500>,
#  'image_id': 'Maine_Coon_136',
#  'label_cat_dog': 0,
#  'filepath': 'data/oxford-iiit-pet/20/Maine_Coon_136.jpg',
#  'label_name': 'maine_coon'}

# %%
initial_samples = initial_samples.remove_columns(["image", "image_id", "label_cat_dog"])
df = initial_samples.to_pandas()
df = df.rename(columns={"label_name": "label"})

df
# Out:
#                                        filepath       label
# 0    data/oxford-iiit-pet/20/Maine_Coon_100.jpg  maine_coon
# 1    data/oxford-iiit-pet/20/Maine_Coon_136.jpg  maine_coon
# 2    data/oxford-iiit-pet/20/Maine_Coon_131.jpg  maine_coon
# 3    data/oxford-iiit-pet/20/Maine_Coon_201.jpg  maine_coon
# 4    data/oxford-iiit-pet/20/Maine_Coon_171.jpg  maine_coon
# ..                                          ...         ...
# 365       data/oxford-iiit-pet/7/Bombay_173.jpg      bombay
# 366       data/oxford-iiit-pet/7/Bombay_178.jpg      bombay
# 367       data/oxford-iiit-pet/7/Bombay_100.jpg      bombay
# 368        data/oxford-iiit-pet/7/Bombay_13.jpg      bombay
# 369       data/oxford-iiit-pet/7/Bombay_186.jpg      bombay
#
# [370 rows x 2 columns]

# %%
df.to_parquet("data/oxford-iiit-pet/initial_samples.parquet")

# %% [markdown]
# ## Make Evaluation Split

# %%
active_learning_dataset["evaluation"][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334>,
#  'image_id': 'newfoundland_31',
#  'label_cat_dog': 1,
#  'filepath': 'data/oxford-iiit-pet/22/newfoundland_31.jpg',
#  'label_name': 'newfoundland'}

# %%
eval_samples = active_learning_dataset["evaluation"].remove_columns(["image", "image_id", "label_cat_dog"])
eval_samples = eval_samples.rename_column("label_name", "label")
eval_samples
# Out:
# Dataset({
#     features: ['filepath', 'label'],
#     num_rows: 3669
# })

# %%
df = eval_samples.to_pandas()
df
# Out:
#                                                filepath               label
# 0           data/oxford-iiit-pet/22/newfoundland_31.jpg        newfoundland
# 1                    data/oxford-iiit-pet/25/pug_57.jpg                 pug
# 2        data/oxford-iiit-pet/1/american_bulldog_80.jpg    american_bulldog
# 3         data/oxford-iiit-pet/15/great_pyrenees_22.jpg      great_pyrenees
# 4               data/oxford-iiit-pet/16/havanese_97.jpg            havanese
# ...                                                 ...                 ...
# 3664           data/oxford-iiit-pet/10/chihuahua_91.jpg           chihuahua
# 3665       data/oxford-iiit-pet/17/japanese_chin_83.jpg       japanese_chin
# 3666       data/oxford-iiit-pet/28/saint_bernard_88.jpg       saint_bernard
# 3667  data/oxford-iiit-pet/21/miniature_pinscher_32.jpg  miniature_pinscher
# 3668           data/oxford-iiit-pet/10/chihuahua_35.jpg           chihuahua
#
# [3669 rows x 2 columns]

# %%
df.to_parquet("data/oxford-iiit-pet/evaluation_samples.parquet")

# %% [markdown]
# ## Make Unlabeled Split

# %%
unlabeled_samples = active_learning_dataset["unlabeled"].remove_columns(["image", "image_id", "label_cat_dog"])
unlabeled_samples = unlabeled_samples.rename_column("label_name", "label")
df = unlabeled_samples.to_pandas()
df
# Out:
#                                                filepath               label
# 0            data/oxford-iiit-pet/20/Maine_Coon_204.jpg          maine_coon
# 1       data/oxford-iiit-pet/1/american_bulldog_138.jpg    american_bulldog
# 2              data/oxford-iiit-pet/18/keeshond_112.jpg            keeshond
# 3              data/oxford-iiit-pet/16/havanese_157.jpg            havanese
# 4     data/oxford-iiit-pet/14/german_shorthaired_132...  german_shorthaired
# ...                                                 ...                 ...
# 3675  data/oxford-iiit-pet/14/german_shorthaired_138...  german_shorthaired
# 3676            data/oxford-iiit-pet/26/Ragdoll_169.jpg             ragdoll
# 3677    data/oxford-iiit-pet/1/american_bulldog_107.jpg    american_bulldog
# 3678    data/oxford-iiit-pet/35/wheaten_terrier_159.jpg     wheaten_terrier
# 3679      data/oxford-iiit-pet/17/japanese_chin_188.jpg       japanese_chin
#
# [3680 rows x 2 columns]

# %% [markdown]
# Remove the initial samples from the unlabeled samples

# %%
initial_filepaths = set(initial_samples['filepath'])
initial_filepaths
# Out:
# {'data/oxford-iiit-pet/0/Abyssinian_125.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_129.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_133.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_141.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_143.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_152.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_160.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_161.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_17.jpg',
#  'data/oxford-iiit-pet/0/Abyssinian_18.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_103.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_107.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_117.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_118.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_12.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_126.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_140.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_16.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_179.jpg',
#  'data/oxford-iiit-pet/1/american_bulldog_19.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_10.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_117.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_126.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_134.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_135.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_136.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_144.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_158.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_167.jpg',
#  'data/oxford-iiit-pet/10/chihuahua_190.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_108.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_11.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_118.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_133.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_148.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_157.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_161.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_170.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_178.jpg',
#  'data/oxford-iiit-pet/11/Egyptian_Mau_186.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_114.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_119.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_12.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_127.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_13.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_155.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_170.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_175.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_186.jpg',
#  'data/oxford-iiit-pet/12/english_cocker_spaniel_187.jpg',
#  'data/oxford-iiit-pet/13/english_setter_107.jpg',
#  'data/oxford-iiit-pet/13/english_setter_117.jpg',
#  'data/oxford-iiit-pet/13/english_setter_134.jpg',
#  'data/oxford-iiit-pet/13/english_setter_138.jpg',
#  'data/oxford-iiit-pet/13/english_setter_146.jpg',
#  'data/oxford-iiit-pet/13/english_setter_150.jpg',
#  'data/oxford-iiit-pet/13/english_setter_158.jpg',
#  'data/oxford-iiit-pet/13/english_setter_168.jpg',
#  'data/oxford-iiit-pet/13/english_setter_170.jpg',
#  'data/oxford-iiit-pet/13/english_setter_185.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_112.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_119.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_129.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_136.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_159.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_171.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_174.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_175.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_180.jpg',
#  'data/oxford-iiit-pet/14/german_shorthaired_186.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_102.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_106.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_112.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_126.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_15.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_152.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_155.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_167.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_177.jpg',
#  'data/oxford-iiit-pet/15/great_pyrenees_184.jpg',
#  'data/oxford-iiit-pet/16/havanese_103.jpg',
#  'data/oxford-iiit-pet/16/havanese_116.jpg',
#  'data/oxford-iiit-pet/16/havanese_128.jpg',
#  'data/oxford-iiit-pet/16/havanese_135.jpg',
#  'data/oxford-iiit-pet/16/havanese_142.jpg',
#  'data/oxford-iiit-pet/16/havanese_156.jpg',
#  'data/oxford-iiit-pet/16/havanese_161.jpg',
#  'data/oxford-iiit-pet/16/havanese_164.jpg',
#  'data/oxford-iiit-pet/16/havanese_165.jpg',
#  'data/oxford-iiit-pet/16/havanese_171.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_102.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_107.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_110.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_118.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_147.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_155.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_16.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_163.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_180.jpg',
#  'data/oxford-iiit-pet/17/japanese_chin_189.jpg',
#  'data/oxford-iiit-pet/18/keeshond_110.jpg',
#  'data/oxford-iiit-pet/18/keeshond_112.jpg',
#  'data/oxford-iiit-pet/18/keeshond_114.jpg',
#  'data/oxford-iiit-pet/18/keeshond_130.jpg',
#  'data/oxford-iiit-pet/18/keeshond_131.jpg',
#  'data/oxford-iiit-pet/18/keeshond_136.jpg',
#  'data/oxford-iiit-pet/18/keeshond_150.jpg',
#  'data/oxford-iiit-pet/18/keeshond_151.jpg',
#  'data/oxford-iiit-pet/18/keeshond_154.jpg',
#  'data/oxford-iiit-pet/18/keeshond_170.jpg',
#  'data/oxford-iiit-pet/19/leonberger_105.jpg',
#  'data/oxford-iiit-pet/19/leonberger_114.jpg',
#  'data/oxford-iiit-pet/19/leonberger_118.jpg',
#  'data/oxford-iiit-pet/19/leonberger_136.jpg',
#  'data/oxford-iiit-pet/19/leonberger_156.jpg',
#  'data/oxford-iiit-pet/19/leonberger_157.jpg',
#  'data/oxford-iiit-pet/19/leonberger_169.jpg',
#  'data/oxford-iiit-pet/19/leonberger_173.jpg',
#  'data/oxford-iiit-pet/19/leonberger_174.jpg',
#  'data/oxford-iiit-pet/19/leonberger_188.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_100.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_101.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_102.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_11.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_117.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_121.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_126.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_130.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_152.jpg',
#  'data/oxford-iiit-pet/2/american_pit_bull_terrier_168.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_1.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_10.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_100.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_131.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_136.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_142.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_150.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_162.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_171.jpg',
#  'data/oxford-iiit-pet/20/Maine_Coon_201.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_109.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_117.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_119.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_121.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_132.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_149.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_155.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_16.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_177.jpg',
#  'data/oxford-iiit-pet/21/miniature_pinscher_190.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_101.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_104.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_107.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_116.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_118.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_127.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_130.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_150.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_156.jpg',
#  'data/oxford-iiit-pet/22/newfoundland_182.jpg',
#  'data/oxford-iiit-pet/23/Persian_128.jpg',
#  'data/oxford-iiit-pet/23/Persian_132.jpg',
#  'data/oxford-iiit-pet/23/Persian_136.jpg',
#  'data/oxford-iiit-pet/23/Persian_138.jpg',
#  'data/oxford-iiit-pet/23/Persian_139.jpg',
#  'data/oxford-iiit-pet/23/Persian_162.jpg',
#  'data/oxford-iiit-pet/23/Persian_163.jpg',
#  'data/oxford-iiit-pet/23/Persian_174.jpg',
#  'data/oxford-iiit-pet/23/Persian_180.jpg',
#  'data/oxford-iiit-pet/23/Persian_200.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_10.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_126.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_137.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_138.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_140.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_144.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_146.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_153.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_167.jpg',
#  'data/oxford-iiit-pet/24/pomeranian_178.jpg',
#  'data/oxford-iiit-pet/25/pug_10.jpg',
#  'data/oxford-iiit-pet/25/pug_119.jpg',
#  'data/oxford-iiit-pet/25/pug_122.jpg',
#  'data/oxford-iiit-pet/25/pug_129.jpg',
#  'data/oxford-iiit-pet/25/pug_134.jpg',
#  'data/oxford-iiit-pet/25/pug_136.jpg',
#  'data/oxford-iiit-pet/25/pug_137.jpg',
#  'data/oxford-iiit-pet/25/pug_165.jpg',
#  'data/oxford-iiit-pet/25/pug_167.jpg',
#  'data/oxford-iiit-pet/25/pug_191.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_107.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_121.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_126.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_136.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_145.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_151.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_156.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_172.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_195.jpg',
#  'data/oxford-iiit-pet/26/Ragdoll_198.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_1.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_101.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_117.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_127.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_150.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_156.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_157.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_175.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_188.jpg',
#  'data/oxford-iiit-pet/27/Russian_Blue_196.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_105.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_109.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_115.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_127.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_138.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_166.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_172.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_179.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_181.jpg',
#  'data/oxford-iiit-pet/28/saint_bernard_186.jpg',
#  'data/oxford-iiit-pet/29/samoyed_10.jpg',
#  'data/oxford-iiit-pet/29/samoyed_101.jpg',
#  'data/oxford-iiit-pet/29/samoyed_124.jpg',
#  'data/oxford-iiit-pet/29/samoyed_13.jpg',
#  'data/oxford-iiit-pet/29/samoyed_134.jpg',
#  'data/oxford-iiit-pet/29/samoyed_143.jpg',
#  'data/oxford-iiit-pet/29/samoyed_15.jpg',
#  'data/oxford-iiit-pet/29/samoyed_16.jpg',
#  'data/oxford-iiit-pet/29/samoyed_176.jpg',
#  'data/oxford-iiit-pet/29/samoyed_18.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_108.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_124.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_138.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_16.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_166.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_169.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_176.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_177.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_182.jpg',
#  'data/oxford-iiit-pet/3/basset_hound_190.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_100.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_117.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_12.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_125.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_149.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_155.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_16.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_177.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_18.jpg',
#  'data/oxford-iiit-pet/30/scottish_terrier_186.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_103.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_113.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_123.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_136.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_139.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_152.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_153.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_174.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_178.jpg',
#  'data/oxford-iiit-pet/31/shiba_inu_18.jpg',
#  'data/oxford-iiit-pet/32/Siamese_100.jpg',
#  'data/oxford-iiit-pet/32/Siamese_112.jpg',
#  'data/oxford-iiit-pet/32/Siamese_127.jpg',
#  'data/oxford-iiit-pet/32/Siamese_131.jpg',
#  'data/oxford-iiit-pet/32/Siamese_147.jpg',
#  'data/oxford-iiit-pet/32/Siamese_151.jpg',
#  'data/oxford-iiit-pet/32/Siamese_158.jpg',
#  'data/oxford-iiit-pet/32/Siamese_161.jpg',
#  'data/oxford-iiit-pet/32/Siamese_188.jpg',
#  'data/oxford-iiit-pet/32/Siamese_204.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_112.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_115.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_137.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_146.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_15.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_165.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_167.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_17.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_173.jpg',
#  'data/oxford-iiit-pet/33/Sphynx_192.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_102.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_112.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_124.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_136.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_144.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_145.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_166.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_181.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_189.jpg',
#  'data/oxford-iiit-pet/34/staffordshire_bull_terrier_191.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_12.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_120.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_127.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_132.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_134.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_136.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_137.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_152.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_157.jpg',
#  'data/oxford-iiit-pet/35/wheaten_terrier_190.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_101.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_103.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_108.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_111.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_113.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_128.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_136.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_146.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_173.jpg',
#  'data/oxford-iiit-pet/36/yorkshire_terrier_190.jpg',
#  'data/oxford-iiit-pet/4/beagle_111.jpg',
#  'data/oxford-iiit-pet/4/beagle_15.jpg',
#  'data/oxford-iiit-pet/4/beagle_155.jpg',
#  'data/oxford-iiit-pet/4/beagle_168.jpg',
#  'data/oxford-iiit-pet/4/beagle_169.jpg',
#  'data/oxford-iiit-pet/4/beagle_178.jpg',
#  'data/oxford-iiit-pet/4/beagle_182.jpg',
#  'data/oxford-iiit-pet/4/beagle_189.jpg',
#  'data/oxford-iiit-pet/4/beagle_191.jpg',
#  'data/oxford-iiit-pet/4/beagle_193.jpg',
#  'data/oxford-iiit-pet/5/Bengal_132.jpg',
#  'data/oxford-iiit-pet/5/Bengal_136.jpg',
#  'data/oxford-iiit-pet/5/Bengal_137.jpg',
#  'data/oxford-iiit-pet/5/Bengal_151.jpg',
#  'data/oxford-iiit-pet/5/Bengal_152.jpg',
#  'data/oxford-iiit-pet/5/Bengal_155.jpg',
#  'data/oxford-iiit-pet/5/Bengal_175.jpg',
#  'data/oxford-iiit-pet/5/Bengal_18.jpg',
#  'data/oxford-iiit-pet/5/Bengal_185.jpg',
#  'data/oxford-iiit-pet/5/Bengal_189.jpg',
#  'data/oxford-iiit-pet/6/Birman_114.jpg',
#  'data/oxford-iiit-pet/6/Birman_115.jpg',
#  'data/oxford-iiit-pet/6/Birman_14.jpg',
#  'data/oxford-iiit-pet/6/Birman_143.jpg',
#  'data/oxford-iiit-pet/6/Birman_148.jpg',
#  'data/oxford-iiit-pet/6/Birman_158.jpg',
#  'data/oxford-iiit-pet/6/Birman_16.jpg',
#  'data/oxford-iiit-pet/6/Birman_162.jpg',
#  'data/oxford-iiit-pet/6/Birman_175.jpg',
#  'data/oxford-iiit-pet/6/Birman_188.jpg',
#  'data/oxford-iiit-pet/7/Bombay_100.jpg',
#  'data/oxford-iiit-pet/7/Bombay_120.jpg',
#  'data/oxford-iiit-pet/7/Bombay_121.jpg',
#  'data/oxford-iiit-pet/7/Bombay_13.jpg',
#  'data/oxford-iiit-pet/7/Bombay_148.jpg',
#  'data/oxford-iiit-pet/7/Bombay_151.jpg',
#  'data/oxford-iiit-pet/7/Bombay_173.jpg',
#  'data/oxford-iiit-pet/7/Bombay_174.jpg',
#  'data/oxford-iiit-pet/7/Bombay_178.jpg',
#  'data/oxford-iiit-pet/7/Bombay_186.jpg',
#  'data/oxford-iiit-pet/8/boxer_116.jpg',
#  'data/oxford-iiit-pet/8/boxer_127.jpg',
#  'data/oxford-iiit-pet/8/boxer_13.jpg',
#  'data/oxford-iiit-pet/8/boxer_132.jpg',
#  'data/oxford-iiit-pet/8/boxer_143.jpg',
#  'data/oxford-iiit-pet/8/boxer_149.jpg',
#  'data/oxford-iiit-pet/8/boxer_173.jpg',
#  'data/oxford-iiit-pet/8/boxer_184.jpg',
#  'data/oxford-iiit-pet/8/boxer_185.jpg',
#  'data/oxford-iiit-pet/8/boxer_189.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_104.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_109.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_144.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_154.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_157.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_18.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_195.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_204.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_205.jpg',
#  'data/oxford-iiit-pet/9/British_Shorthair_207.jpg'}

# %%
# Filter out rows that are in initial_samples
unlabeled_samples = unlabeled_samples.filter(
    lambda x: x['filepath'] not in initial_filepaths
)

unlabeled_samples
# Out:
# Filter:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Dataset({
#     features: ['filepath', 'label'],
#     num_rows: 3310
# })

# %%
df = unlabeled_samples.to_pandas()
df = df.drop(columns=["label"])
df
# Out:
#                                                filepath
# 0            data/oxford-iiit-pet/20/Maine_Coon_204.jpg
# 1       data/oxford-iiit-pet/1/american_bulldog_138.jpg
# 2              data/oxford-iiit-pet/16/havanese_157.jpg
# 3     data/oxford-iiit-pet/14/german_shorthaired_132...
# 4           data/oxford-iiit-pet/3/basset_hound_161.jpg
# ...                                                 ...
# 3305     data/oxford-iiit-pet/13/english_setter_186.jpg
# 3306  data/oxford-iiit-pet/14/german_shorthaired_138...
# 3307            data/oxford-iiit-pet/26/Ragdoll_169.jpg
# 3308    data/oxford-iiit-pet/35/wheaten_terrier_159.jpg
# 3309      data/oxford-iiit-pet/17/japanese_chin_188.jpg
#
# [3310 rows x 1 columns]

# %%
df.to_parquet("data/oxford-iiit-pet/unlabeled_samples.parquet")
