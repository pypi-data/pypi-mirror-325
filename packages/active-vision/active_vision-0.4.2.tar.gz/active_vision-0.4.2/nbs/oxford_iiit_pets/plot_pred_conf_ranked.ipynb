# %%
import pandas as pd

df = pd.read_parquet("uncertain_df.parquet")
df
# Out:
#                                               filepath  \
# 2456  data/oxford-iiit-pet/9/British_Shorthair_125.jpg
# 2725      data/oxford-iiit-pet/27/Russian_Blue_151.jpg
# 2764         data/oxford-iiit-pet/31/shiba_inu_166.jpg
# 548             data/oxford-iiit-pet/33/Sphynx_110.jpg
# 2539           data/oxford-iiit-pet/16/havanese_10.jpg
# ...                                                ...
# 924              data/oxford-iiit-pet/7/Bombay_119.jpg
# 3100   data/oxford-iiit-pet/1/american_bulldog_142.jpg
# 701          data/oxford-iiit-pet/10/chihuahua_108.jpg
# 1394         data/oxford-iiit-pet/0/Abyssinian_113.jpg
# 2252         data/oxford-iiit-pet/31/shiba_inu_194.jpg
#
#                       pred_label  pred_conf  pred_probs  uncertainty_score
# 2456                  maine_coon   0.031556    0.182966           0.968444
# 2725           british_shorthair   0.031684    0.187030           0.968316
# 2764   american_pit_bull_terrier   0.031717    0.188463           0.968283
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                             filepath  \
# 0   data/oxford-iiit-pet/9/British_Shorthair_125.jpg
# 1       data/oxford-iiit-pet/27/Russian_Blue_151.jpg
# 2          data/oxford-iiit-pet/31/shiba_inu_166.jpg
# 3             data/oxford-iiit-pet/33/Sphynx_110.jpg
# 4            data/oxford-iiit-pet/16/havanese_10.jpg
# ..                                               ...
# 95             data/oxford-iiit-pet/7/Bombay_119.jpg
# 96   data/oxford-iiit-pet/1/american_bulldog_142.jpg
# 97         data/oxford-iiit-pet/10/chihuahua_108.jpg
# 98         data/oxford-iiit-pet/0/Abyssinian_113.jpg
# 99         data/oxford-iiit-pet/31/shiba_inu_194.jpg
#
#                     pred_label  pred_conf  pred_probs  uncertainty_score
# 0                   maine_coon   0.031556    0.182966           0.968444
# 1            british_shorthair   0.031684    0.187030           0.968316
# 2    american_pit_bull_terrier   0.031717    0.188463           0.968283
# ...

# %%
# Sort values for better line visualization
df_sorted = df.sort_values('pred_conf').reset_index(drop=True)

# Create the line plot
plt.figure(figsize=(12, 6))
plt.plot(df_sorted.index, df_sorted['pred_conf'], color='blue', label='Prediction Confidence')
plt.plot(df_sorted.index, df_sorted['pred_probs'], color='red', label='Prediction Probability')

plt.title('Prediction Confidences and Probabilities')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
