# %%
from alive_progress import *
import time
from tqdm import tqdm

# %%
for x in [1000]: #, 1500, 700, 0:
    with alive_bar(x, bar='blocks', force_tty=True) as bar:
        for i in range(1000):
            time.sleep(.005)
            bar()
# Out:
# |▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉| 1000/1000 [100%] in 6.2s (162.59/s)

# %%
# for x in [1000]: #, 1500, 700, 0:
    # with alive_bar(x, bar='blocks', force_tty=True) as bar:
for i in alive_it(range(5), force_tty=True, bar='solid'):
    time.sleep(.005)
    for j in alive_it(range(10), force_tty=True, bar='circles'):
        time.sleep(0.05)
        for k in alive_it(range(20), force_tty=True, bar='c=filling'):
            time.sleep(0.1)
        # bar()
# Out:
# <⚠︎                                       > (!) 0/5 [0%] in 0.1s (0.00/s)
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[24], line 5
#       3 for i in alive_it(range(5), force_tty=True, bar='solid'):
#       4     time.sleep(.005)
# ----> 5     for j in alive_it(range(10), force_tty=True, bar='circles'):
#       6         time.sleep(0.05)
#       7         for k in alive_it(range(20), force_tty=True, bar='c=filling'):
#
# File ~/anaconda3/lib/python3.11/site-packages/alive_progress/core/progress.py:564, in __AliveBarIteratorAdapter.__iter__(self)
#     561 if '_bar' in self.__dict__:  # this iterator has already initiated.
#     562     return
# --> 564 with self._inner_bar as self._bar:
#     565     del self._inner_bar
#     566     for item in self._it:
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
# ...

# %%
desc_width=25
perm_width=15
shot_tqdm = tqdm(range(37343, 37345), desc="Shots".rjust(desc_width), position=0)
for sn in shot_tqdm:
    time.sleep(.005)
    shot_desc = f"On #{sn} |".rjust(desc_width - perm_width) + " Shots".rjust(perm_width)
    shot_tqdm.set_description(desc=shot_desc)
    # trees_desc = str(i) + " Trees"
    # trees_desc.rjust(20)
    tree_tqdm = tqdm(['KSTAR', 'PCS_KSTAR', 'EFIT01'], desc="Trees".rjust(desc_width), leave=False, position=1)
    for tree in tree_tqdm:
        time.sleep(0.05)
        tree_desc = f"On {tree} |".rjust(desc_width - perm_width) + " Trees".rjust(perm_width)
        # tree_desc
        # tree_desc += " Trees"
        tree_tqdm.set_description(desc=tree_desc)
        pn_tqdm = tqdm(range(3), desc="Pointnames".rjust(desc_width), leave=False, position=2)
        for pn in pn_tqdm:
            time.sleep(0.05)
            # pn_desc = f"{pn} |"
            # pn_desc.rjust(desc_width - perm_width)
            # pn_desc += " Pointnames"
            # pn_tqdm.set_description(desc=pn_desc.rjust(desc_width))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 20/20 [00:02<00:00,  9.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#  20%|██        | 1/5 [00:21<01:26, 21.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
