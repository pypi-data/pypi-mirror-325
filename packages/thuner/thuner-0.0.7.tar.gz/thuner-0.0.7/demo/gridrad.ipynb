# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import shutil
import numpy as np
import thuner.data as data
import thuner.option as option
import thuner.analyze as analyze
import thuner.parallel as parallel
import thuner.visualize as visualize

import thuner.log as log

notebook_name = "gridrad_demo.ipynb"
# Out:
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.6! This
# is a placeholder version of the package and is not yet functional. Please visit
# github.com/THUNER-project/THUNER to report issues or contribute.
#
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. For examples and instructions, see
# github.com/THUNER-project/THUNER. If you use this package in your research, consider
# citing the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2

# %%
# Parent directory for saving outputs
base_local = Path.home() / "THUNER_output"
year=2010
event_directories = data.gridrad.get_event_directories(year, base_local=base_local)
event_directory = event_directories[0]
start, end, event_start = data.gridrad.get_event_times(event_directory)
# start = "2010-01-20T19:20:00"
# end = "2010-01-21T00:30:00"

period = parallel.get_period(start, end)
intervals = parallel.get_time_intervals(start, end, period=period)

output_parent = base_local / f"runs/gridrad_demo"

# %%
# if output_parent.exists():
# shutil.rmtree(output_parent)
options_directory = output_parent / "options"

# Create and save the dataset options
times_dict = {"start": start, "end": end}
gridrad_dict = {"event_start": event_start}
gridrad_options = data.gridrad.GridRadSevereOptions(**times_dict, **gridrad_dict)
era5_dict = {"latitude_range": [27, 39], "longitude_range": [-102, -89]}
era5_pl_options = data.era5.ERA5Options(**times_dict, **era5_dict)
era5_dict.update({"data_format": "single-levels"})
era5_sl_options = data.era5.ERA5Options(**times_dict, **era5_dict)
datasets = [gridrad_options, era5_pl_options, era5_sl_options]
data_options = option.data.DataOptions(datasets=datasets)
data_options.to_yaml(options_directory / "data.yml")

# Create and save the grid_options dictionary
kwargs = {"name": "geographic", "regrid": False, "altitude_spacing": None}
kwargs.update({"geographic_spacing": None})
grid_options = option.grid.GridOptions(**kwargs)
grid_options.to_yaml(options_directory / "grid.yml")

# Create the track_options dictionary
track_options = option.default.track(dataset="gridrad")
# Modify the default options for gridrad. Because grids so large we now use a distinct
# global flow box for each object.
track_options.levels[1].objects[0].tracking.global_flow_margin = 70
track_options.levels[1].objects[0].tracking.unique_global_flow = False
# If testing, remove the profile and tag attributes
# track_options.levels[1].objects[0].attributes["mcs"].pop("profile")
# track_options.levels[1].objects[0].attributes["mcs"].pop("tag")
track_options.to_yaml(options_directory / "track.yml")

visualize_options = None
# Out:
# 2025-02-06 17:32:33,864 - thuner.data.gridrad - INFO - Generating era5 filepaths.
# 2025-02-06 17:32:33,868 - thuner.data.era5 - INFO - Generating era5 filepaths.
# 2025-02-06 17:32:33,870 - thuner.data.era5 - INFO - Generating era5 filepaths.
# 2025-02-06 17:32:33,899 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 17:32:33,901 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.

# %%
times = data.utils.generate_times(data_options.dataset_by_name("gridrad"))
args = [times, data_options, grid_options, track_options, visualize_options]
parallel.track(*args, output_directory=output_parent)
# Out:
# 2025-02-06 17:32:45,852 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_0.
# 2025-02-06 17:32:45,852 - thuner.track - INFO - Beginning simultaneous tracking.
# 2025-02-06 17:32:45,857 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_1.
# 2025-02-06 17:32:45,857 - thuner.track - INFO - Beginning simultaneous tracking.
# 2025-02-06 17:32:45,924 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_2.
# 2025-02-06 17:32:45,925 - thuner.track - INFO - Beginning simultaneous tracking.
# 2025-02-06 17:32:46,036 - thuner.track - INFO - Beginning thuner run. Saving output to /home/ewan/THUNER_output/runs/gridrad_demo/interval_3.
# 2025-02-06 17:32:46,036 - thuner.track - INFO - Beginning simultaneous tracking.
# 2025-02-06 17:32:46,418 - thuner.track - INFO - Processing 2010-01-20T19:00:00.
# 2025-02-06 17:32:46,419 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T19:00:00.
# 2025-02-06 17:32:46,419 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T190000Z.nc
# 2025-02-06 17:32:46,434 - thuner.track - INFO - Processing 2010-01-20T18:00:00.
# 2025-02-06 17:32:46,435 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T18:00:00.
# 2025-02-06 17:32:46,435 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T180000Z.nc
# 2025-02-06 17:32:46,635 - thuner.track - INFO - Processing 2010-01-20T20:00:00.
# 2025-02-06 17:32:46,639 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T20:00:00.
# 2025-02-06 17:32:46,640 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T200000Z.nc
# 2025-02-06 17:32:46,872 - thuner.track - INFO - Processing 2010-01-20T21:00:00.
# 2025-02-06 17:32:46,873 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T21:00:00.
# 2025-02-06 17:32:46,873 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T210000Z.nc
# 2025-02-06 17:32:51,787 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:32:51,788 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:32:51,996 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:32:51,996 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:32:52,124 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:32:52,126 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:32:52,339 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:32:52,339 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:33:11,072 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:33:11,089 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:33:11,100 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:33:11,100 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:33:11,133 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:33:11,136 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2025-02-06 17:33:11,193 - thuner.track - INFO - Processing 2010-01-20T20:10:00.
# 2025-02-06 17:33:11,194 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T20:10:00.
# 2025-02-06 17:33:11,194 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T201000Z.nc
# 2025-02-06 17:33:11,254 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:33:11,279 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:33:11,304 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:33:11,321 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:33:11,321 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:33:11,375 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:33:11,381 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2025-02-06 17:33:11,395 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:33:11,505 - thuner.track - INFO - Processing 2010-01-20T21:10:00.
# 2025-02-06 17:33:11,506 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T21:10:00.
# 2025-02-06 17:33:11,506 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T211000Z.nc
# 2025-02-06 17:33:11,520 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:33:11,520 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:33:12,074 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:33:12,170 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:33:12,174 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2025-02-06 17:33:12,288 - thuner.track - INFO - Processing 2010-01-20T18:10:00.
# 2025-02-06 17:33:12,292 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T18:10:00.
# 2025-02-06 17:33:12,293 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T181000Z.nc
# 2025-02-06 17:33:12,875 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:33:13,439 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:33:13,440 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:33:14,337 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:33:14,344 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2025-02-06 17:33:14,454 - thuner.track - INFO - Processing 2010-01-20T19:10:00.
# 2025-02-06 17:33:14,455 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-20T19:10:00.
# 2025-02-06 17:33:14,456 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100120T191000Z.nc
# 2025-02-06 17:33:14,799 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2010-01-20T20:00:00.
# 2025-02-06 17:33:14,800 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2025-02-06 17:33:15,424 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2010-01-20T21:00:00.
# 2025-02-06 17:33:15,425 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2025-02-06 17:33:15,727 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2010-01-20T18:00:00.
# 2025-02-06 17:33:15,729 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2025-02-06 17:33:17,356 - thuner.data.era5 - INFO - Updating era5_pl dataset for 2010-01-20T19:00:00.
# 2025-02-06 17:33:17,357 - thuner.data.era5 - INFO - Subsetting era5_pl data.
# 2025-02-06 17:33:19,225 - thuner.data.era5 - INFO - Updating era5_sl dataset for 2010-01-20T20:00:00.
# 2025-02-06 17:33:19,226 - thuner.data.era5 - INFO - Subsetting era5_sl data.
# 2025-02-06 17:33:19,514 - thuner.data.era5 - INFO - Updating era5_sl dataset for 2010-01-20T21:00:00.
# 2025-02-06 17:33:19,515 - thuner.data.era5 - INFO - Subsetting era5_sl data.
# 2025-02-06 17:33:19,673 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:33:19,674 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:33:19,755 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:33:19,776 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:33:19,797 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:33:19,797 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:33:19,810 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_2/masks/mcs.zarr.
# 2025-02-06 17:33:20,019 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:33:20,023 - thuner.match.match - INFO - No previous mask, or no objects in previous mask.
# 2025-02-06 17:33:20,031 - thuner.data.era5 - INFO - Updating era5_sl dataset for 2010-01-20T18:00:00.
# 2025-02-06 17:33:20,033 - thuner.data.era5 - INFO - Subsetting era5_sl data.
# 2025-02-06 17:33:20,042 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:33:20,042 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:33
- thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T03:30:00.
# 2025-02-06 17:36:22,807 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T033000Z.nc
# 2025-02-06 17:36:24,451 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:36:24,451 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:36:24,640 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:36:24,640 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:36:27,670 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:36:27,855 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:36:28,115 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:36:28,283 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:36:28,283 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:36:28,289 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_8/masks/mcs.zarr.
# 2025-02-06 17:36:28,302 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:36:28,875 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:36:29,071 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:36:29,071 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:36:29,083 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_9/masks/mcs.zarr.
# 2025-02-06 17:36:29,422 - thuner.match.match - INFO - Updating object record.
# 2025-02-06 17:36:29,472 - thuner.attribute.attribute - INFO - Recording mcs attributes.
# 2025-02-06 17:36:29,938 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:36:30,022 - thuner.track - INFO - Processing 2010-01-21T02:50:00.
# 2025-02-06 17:36:30,023 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T02:50:00.
# 2025-02-06 17:36:30,023 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T025000Z.nc
# 2025-02-06 17:36:30,236 - thuner.match.match - INFO - Updating object record.
# 2025-02-06 17:36:30,258 - thuner.attribute.attribute - INFO - Recording mcs attributes.
# 2025-02-06 17:36:30,754 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T03:00:00 to 2010-01-21T04:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:30,840 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T03:00:00 to 2010-01-21T04:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:30,841 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2025-02-06 17:36:31,105 - thuner.write.filepath - INFO - Aggregating filepath records.
# 2025-02-06 17:36:31,821 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:36:31,821 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:36:34,689 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:36:34,873 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:36:35,196 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:36:35,197 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:36:35,202 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_8/masks/mcs.zarr.
# 2025-02-06 17:36:35,602 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:36:35,869 - thuner.match.match - INFO - Updating object record.
# 2025-02-06 17:36:35,890 - thuner.attribute.attribute - INFO - Recording mcs attributes.
# 2025-02-06 17:36:36,337 - thuner.track - INFO - Processing 2010-01-21T03:00:00.
# 2025-02-06 17:36:36,338 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T03:00:00.
# 2025-02-06 17:36:36,338 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T030000Z.nc
# 2025-02-06 17:36:37,853 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:37,855 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:36:37,855 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:36:40,803 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:36:40,970 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:36:41,340 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:36:41,340 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:36:41,347 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_8/masks/mcs.zarr.
# 2025-02-06 17:36:41,365 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T02:00:00 to 2010-01-21T03:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:41,839 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:36:42,124 - thuner.match.match - INFO - Updating object record.
# 2025-02-06 17:36:42,142 - thuner.attribute.attribute - INFO - Recording mcs attributes.
# 2025-02-06 17:36:42,659 - thuner.track - INFO - Processing 2010-01-21T03:10:00.
# 2025-02-06 17:36:42,659 - thuner.data.gridrad - INFO - Updating gridrad dataset for 2010-01-21T03:10:00.
# 2025-02-06 17:36:42,659 - thuner.data.gridrad - INFO - Converting gridrad data from nexrad_3d_v4_2_20100121T031000Z.nc
# 2025-02-06 17:36:44,153 - thuner.track - INFO - Processing hierarchy level 0.
# 2025-02-06 17:36:44,153 - thuner.track - INFO - Tracking convective.
# 2025-02-06 17:36:47,258 - thuner.track - INFO - Tracking middle.
# 2025-02-06 17:36:47,419 - thuner.track - INFO - Tracking anvil.
# 2025-02-06 17:36:47,787 - thuner.track - INFO - Processing hierarchy level 1.
# 2025-02-06 17:36:47,787 - thuner.track - INFO - Tracking mcs.
# 2025-02-06 17:36:47,791 - thuner.write.mask - INFO - Writing mcs masks to /home/ewan/THUNER_output/runs/gridrad_demo/interval_8/masks/mcs.zarr.
# 2025-02-06 17:36:48,225 - thuner.match.match - INFO - Matching mcs objects.
# 2025-02-06 17:36:48,506 - thuner.match.match - INFO - Updating object record.
# 2025-02-06 17:36:48,524 - thuner.attribute.attribute - INFO - Recording mcs attributes.
# 2025-02-06 17:36:48,989 - thuner.write.attribute - INFO - Writing mcs attributes from 2010-01-21T03:00:00 to 2010-01-21T04:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:49,068 - thuner.write.filepath - INFO - Writing gridrad filepaths from 2010-01-21T03:00:00 to 2010-01-21T04:00:00, inclusive and non-inclusive, respectively.
# 2025-02-06 17:36:49,069 - thuner.write.attribute - INFO - Aggregating attribute files.
# 2025-02-06 17:36:49,334 - thuner.write.filepath - INFO - Aggregating filepath records.
# 2025-02-06 17:36:51,726 - thuner.parallel - INFO - Stitching all attribute, mask and record files.
# 2025-02-06 17:36:51,730 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 17:36:51,730 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 17:36:58,583 - thuner.parallel - INFO - Stitching record files.
# 2025-02-06 17:36:58,665 - thuner.parallel - INFO - Stitching attribute files.
# 2025-02-06 17:37:01,555 - thuner.parallel - INFO - Stitching mask files.

# %%
analysis_options = analyze.mcs.AnalysisOptions()
analyze.mcs.process_velocities(output_parent, profile_dataset=None)
analyze.mcs.quality_control(output_parent, analysis_options)
# analyze.mcs.classify_all(output_parent, analysis_options)
# Out:
# 2025-02-06 18:21:14,508 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 18:21:14,509 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 18:21:14,706 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 18:21:14,706 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.

# %%
figure_name = f"mcs_gridrad_{event_start.replace('-', '')}"
kwargs = {"style": "presentation", "attributes": ["velocity", "offset"]}
figure_options = visualize.option.horizontal_attribute_options(figure_name, **kwargs)
start_time = np.datetime64(start)
end_time = np.datetime64(end)
args = [output_parent, start_time, end_time, figure_options]
args_dict = {"parallel_figure": True, "dt": 7200, "by_date": False, "num_processes": 4}
visualize.attribute.mcs_series(*args, **args_dict)
# Out:
# 2025-02-06 16:54:25,952 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:25,953 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:26,447 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:00:00.000000000.
# 2025-02-06 16:54:28,033 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:28,034 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:29,011 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:00:00.000000000.
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.6! This
# is a placeholder version of the package and is not yet functional. Please visit
# github.com/THUNER-project/THUNER to report issues or contribute.
#
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. For examples and instructions, see
# github.com/THUNER-project/THUNER. If you use this package in your research, consider
# citing the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2
#
#
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.6! This
# is a placeholder version of the package and is not yet functional. Please visit
# github.com/THUNER-project/THUNER to report issues or contribute.
#
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. For examples and instructions, see
# github.com/THUNER-project/THUNER. If you use this package in your research, consider
# citing the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2
#
#
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.6! This
# is a placeholder version of the package and is not yet functional. Please visit
# github.com/THUNER-project/THUNER to report issues or contribute.
#
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. For examples and instructions, see
# github.com/THUNER-project/THUNER. If you use this package in your research, consider
# citing the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2
#
#
# Welcome to the Thunderstorm Event Reconnaissance (THUNER) package v0.0.6! This
# is a placeholder version of the package and is not yet functional. Please visit
# github.com/THUNER-project/THUNER to report issues or contribute.
#
# THUNER is a flexible toolkit for performing multi-feature detection, tracking, tagging
# and analysis of events within meteorological datasets. The intended application is to
# convective weather events. For examples and instructions, see
# github.com/THUNER-project/THUNER. If you use this package in your research, consider
# citing the following papers;
#
# Short et al. (2023), MWR, doi: 10.1175/MWR-D-22-0146.1
# Raut et al. (2021), JAMC, doi: 10.1175/JAMC-D-20-0119.1
# Fridlind et al. (2019), AMT, doi: 10.5194/amt-12-2979-2019
# Dixon and Wiener (1993), JTECH, doi: 10.1175/1520-0426(1993)010<0785:TTITAA>2.0.CO;2
# Leese et al. (1971), JAMC, doi: 10.1175/1520-0450(1971)010<0118:AATFOC>2.0.CO;2
# 2025-02-06 16:54:36,923 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:10:00.000000000.
# 2025-02-06 16:54:36,969 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:20:00.000000000.
# 2025-02-06 16:54:37,023 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:30:00.000000000.
# 2025-02-06 16:54:39,012 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:40:00.000000000.
# 2025-02-06 16:54:39,947 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:39,947 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:40,008 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:40,009 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:40,067 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:40,068 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:41,861 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:20:00.000000000.
# 2025-02-06 16:54:41,915 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:10:00.000000000.
# 2025-02-06 16:54:42,003 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:30:00.000000000.
# 2025-02-06 16:54:42,468 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:42,469 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:43,734 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:40:00.000000000.
# 2025-02-06 16:54:44,348 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T18:50:00.000000000.
# 2025-02-06 16:54:45,259 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:00:00.000000000.
# 2025-02-06 16:54:45,361 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:10:00.000000000.
# 2025-02-06 16:54:46,820 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:20:00.000000000.
# 2025-02-06 16:54:46,970 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:46,971 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:48,067 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T18:50:00.000000000.
# 2025-02-06 16:54:48,117 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:48,117 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:48,217 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:48,218 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:49,217 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:10:00.000000000.
# 2025-02-06 16:54:49,262 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:00:00.000000000.
# 2025-02-06 16:54:49,550 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:49,550 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:49,962 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:30:00.000000000.
# 2025-02-06 16:54:50,553 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:20:00.000000000.
# 2025-02-06 16:54:50,996 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:40:00.000000000.
# 2025-02-06 16:54:52,157 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:52,158 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:52,779 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T19:50:00.000000000.
# 2025-02-06 16:54:52,898 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:30:00.000000000.
# 2025-02-06 16:54:53,020 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:53,020 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:54,546 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:40:00.000000000.
# 2025-02-06 16:54:54,886 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T20:00:00.000000000.
# 2025-02-06 16:54:56,036 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:56,036 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:56,838 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T20:10:00.000000000.
# 2025-02-06 16:54:56,952 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T19:50:00.000000000.
# 2025-02-06 16:54:57,434 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:57,434 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:58,241 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T20:00:00.000000000.
# 2025-02-06 16:54:58,784 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T20:20:00.000000000.
# 2025-02-06 16:54:58,955 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:54:58,956 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:54:59,771 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20T20:10:00.000000000.
# 2025-02-06 16:55:00,625 - thuner.option.grid - WARNING - altitude_spacing not specified. Will attempt to infer from input.
# 2025-02-06 16:55:00,626 - thuner.option.grid - WARNING - shape not specified. Will attempt to infer from input.
# 2025-02-06 16:55:00,779 - thuner.visualize.attribute - INFO - Visualizing MCS at time 2010-01-20T20:30:00.000000000.
# 2025-02-06 16:55:01,399 - thuner.visualize.attribute - INFO - Saving mcs_gridrad_20100120 figure for 2010-01-20