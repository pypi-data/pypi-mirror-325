# %%
from pymongo import MongoClient

client = MongoClient("mongodb://fire:fire123@103.182.210.226:27017,103.182.210.226:27018,103.182.210.226:27019/?authMechanism=DEFAULT&authSource=admin&tls=true&tlsCAFile=C%3A%5CUsers%5CUser%5CDownloads%5CrootCA.pem&tlsCertificateKeyFile=C%3A%5CUsers%5CUser%5CDownloads%5Cmongodb.pem&tlsInsecure=true")['optimize_dev2_LIC3938']["ai_script"]

doc=[{
  "_id": "SCR1001",#from UI
  "name": "scr001",#from UI
  "scriptType": "Web",
  "desc": "",
  "type": "Script",
  "testCaseType": "Automation",
  "executionOrder": 0,
  "stepCount": 0,
  "hierarchy": 0,
  "preConditionCount": 0,
  "postConditionCount": 0,
  "dependentScriptCount": 0,
  "projectLabels": [],
  "imported": False,
  "assigneeCount": 0,
  "projectId": "PJT1003",
  "authorizationInfo": {
    "authType": "No Auth",
    "parentId": "MOD1003",#from  UI
    "inherited": True
  },
  "prefix": "SCR1001",
  "pair": False,
  "createdBy": "USR17944",
  "modifiedBy": "USR17944",
  "createdByUname": "Shankar Dev2 FF",
  "modifiedByUname": "Shankar Dev2 FF",
  "createdOn": "2024-12-30T18:17:32.400Z",
  "modifiedOn": "2024-12-30T18:17:32.400Z",
#   "state": "APPROVED",
#   "path": "/Root/mod001/scr001",
#   "searchKey": "/MOD1003/MODf3478064-9e50-491c-9efd-5ceba74629ad/SCR1001",
#   "parentId": "MODf3478064-9e50-491c-9efd-5ceba74629ad",
#   "parentName": "mod001",
  #"version": "1.0",
  "_class": "com.tyss.optimize.data.models.db.model.Script",
  "steps": [
    {
      "name": "OpenBrowser",
      "type": "Group",
      "nlpName": "OpenBrowser",
      "executionOrder": 1,
      "nlpId": "STP_GRP0f071f1b-5378-41bc-8b79-86ac6fb0183f",// from project
      "stepInputs": [
        {
          "value": "MARK_THIS_STEP_AS_FAILED_AND_CONTINUE_SCRIPT_EXECUTION",
          "name": "ifCheckPointIsFailed",
          "type": "java.lang.String"
        }
      ],
      "skip": False,
      "returnType": "void",
      "libraryId": "LIB693a35f4-d083-43f9-824e-5022b1b76499",// from project
      "stepGroupId": "STP_GRP0f071f1b-5378-41bc-8b79-86ac6fb0183f",// from project
      "displayName": "OpenBrowser",
      "defaultDisplayName": "OpenBrowser",
      "stepId": "STP74927M11D30H18M17S45M87R93",// 
      "toolTip": "Open and Close Browser : OpenBrowser : Web",
      "defaultToolTip": "Open and Close Browser : OpenBrowser : Web",
      "hierarchy": 0,
      "marginLeft": 0,
      "mustExecute": False,
      "isAfterBreakStep": False,
      "isAfterContinueStep": False,
      "imported": False,
      "isDisabled": False
    },
    {
      "name": "nlpdisplayname.rename",
      "type": "step",
      "nlpName": "NavigateToURL",
      "executionOrder": 2,
      "nlpId": "NLP1099",
      "passMessage": "Navigated to URL *url*",
      "failMessage": "Failed to navigate to URL *url*",
      "stepInputs": [
        {
          "value": "flipkart.com",
          "name": "url",
          "type": "java.lang.String"
        },
        {   #append it by defaualt
          "value": "MARK_THIS_STEP_AS_FAILED_AND_CONTINUE_SCRIPT_EXECUTION",
          "name": "ifCheckPointIsFailed",
          "type": "java.lang.String"
        }
      ],
      "skip": False,
      "returnType": "void",
      "platform": "Web",
      "searchName": "Navigate to *url*",
      "displayName": "Navigate to URL flipkart.com",
      "actualFailedResult": "N/A",
      "defaultDisplayName": "Navigate to URL *url*",
      "stepId": "STP59074M11D30H18M18S24M326R37",
      "toolTip": "Navigate to URL flipkart.com",
      "defaultToolTip": "Navigate to URL *url*",
      "hierarchy": 0,
      "marginLeft": 0,
      "mustExecute": False,
      "isAfterBreakStep": False,
      "isAfterContinueStep": False,
      "imported": False,
      "isDisabled": False
    },
    {
      "name": "Wait for 5 seconds",
      "type": "step",
      "nlpName": "Sleep",
      "executionOrder": 3,
      "nlpId": "NLP1008",
      "passMessage": "Completed wait for *seconds* seconds",
      "failMessage": "Failed to wait for *seconds* seconds",
      "stepInputs": [
        {
          "value": "5",
          "name": "seconds",
          "type": "java.lang.Integer"
        },
        {
          "value": "MARK_THIS_STEP_AS_FAILED_AND_CONTINUE_SCRIPT_EXECUTION",
          "name": "ifCheckPointIsFailed",
          "type": "java.lang.String"
        }
      ],
      "skip": False,
      "returnType": "void",
      "platform": "Web",
      "searchName": "Wait for *seconds* seconds",
      "displayName": "Wait for 5 seconds",
      "actualFailedResult": "Failed to wait for *seconds* seconds",
      "defaultDisplayName": "Wait for *seconds* seconds",
      "stepId": "STP96595M11D30H18M18S2M938R38",
      "toolTip": "Wait for 5 seconds",
      "defaultToolTip": "Wait for *seconds* seconds",
      "hierarchy": 0,
      "marginLeft": 0,
      "mustExecute": False,
      "isAfterBreakStep": False,
      "isAfterContinueStep": False,
      "imported": False,
      "isDisabled": False
    }
  ]
}
]

client.insert_many(doc)
# Out:
# InsertManyResult(['SCR1001'], acknowledged=True)

# %%
import uuid
id=f"ELE{uuid.uuid4()}"
{
  "_id": id,
#   "executionOrder": 1,
#   "hierarchy": 2,
  "name": "eleoo1",
  "desc": "",
  "type": "link",
  "locatorsCount": 1,
  "locators": [
    {
      "value": "abc",
      "type": "static",
      "name": "id",
      "status": "NOT_USED",
      "isRecorded": "N",
      "priority": "",
      "defaultAddedFirst": False,
      "defaultAddedSecond": False
    }
  ],
#   "isShared": "N",
  "isRecorded": "N",
  "folder": False,
  "platform": "Web",
  "projectType": "Web",
  "projectId": "PJT1003",
  "elementId": id,
#   "users": [
    # "shankar.r@fireflink.com"
#   ],
#   "excludeUsers": [],
#   "deleteUsers": [],
  "activeStatus": True,
  "updatedStatus": False,
  "imported": False,
  "createdBy": "USR17944",
  "modifiedBy": "USR17944",
  "createdByUname": "Shankar Dev2 FF",
  "modifiedByUname": "Shankar Dev2 FF",
  "createdOn": "2024-12-30T18:23:37.429Z",
  "modifiedOn": "2024-12-30T18:23:37.429Z",
#   "state": "APPROVED",
#   "path": "/Root/page001/eleoo1",
#   "searchKey": "/PAG1003/PAG93ae2f14-692b-419e-b6cf-04bba3cb8fef/ELEee6a9860-d6e3-40d4-92f7-720e1d855e4f",
#   "parentId": "PAG93ae2f14-692b-419e-b6cf-04bba3cb8fef",
#   "parentName": "page001",
#   "version": "1.0",
  "_class": "com.tyss.optimize.data.models.db.model.Element"
}

# %%
data= [
        {
            "aiReferenceElement": "",
            "element": "",
            "input": "https://www.amazon.com",
            "nlpName": "NavigateToURL"
        },
        {
            "aiReferenceElement": "JSHandle@<input value=\"\" dir=\"auto\" type=\"text\" tabindex=\"0\" role=\"searchbox\" autocomplete=\"off\" spellcheck=\"false\" aria-haspopup=\"grid\" name=\"field-keywords\" aria-expanded=\"false\" id=\"twotabsearchtextbox\" aria-autocomplete=\"list\" aria-label=\"Search Amazon\" placeholder=\"Search Amazon\" class=\"nav-input nav-progressive-attribute\" aria-controls=\"sac-autocomplete-results-container\" browser-user-highlight-id=\"playwright-highlight-2\"/>",
            "element": {
                "PopupCoordinatesArr": {
                    "clickX":None,
                    "clickY":None,
                    "scrollX": 0,
                    "scrollY": 0,
                    "winInnerHeight": 1100,
                    "winInnerWidth": 1280
                },
                "absoluteXpath": "/HTML/BODY/DIV[1]/HEADER/DIV/DIV[1]/DIV[2]/DIV/FORM/DIV[2]/DIV[1]/DIV/INPUT",
                "attributes": [
                    {
                        "name": "type",
                        "updateDate": None,
                        "value": "text"
                    },
                    {
                        "name": "id",
                        "updateDate": None,
                        "value": "twotabsearchtextbox"
                    },
                    {
                        "name": "value",
                        "updateDate": None,
                        "value": ""
                    },
                    {
                        "name": "name",
                        "updateDate": None,
                        "value": "field-keywords"
                    },
                    {
                        "name": "autocomplete",
                        "updateDate": None,
                        "value": "off"
                    },
                    {
                        "name": "placeholder",
                        "updateDate": None,
                        "value": "Search Amazon"
                    },
                    {
                        "name": "class",
                        "updateDate": None,
                        "value": "nav-input nav-progressive-attribute"
                    },
                    {
                        "name": "dir",
                        "updateDate": None,
                        "value": "auto"
                    },
                    {
                        "name": "tabindex",
                        "updateDate": None,
                        "value": "0"
                    },
                    {
                        "name": "aria-label",
                        "updateDate": None,
                        "value": "Search Amazon"
                    },
                    {
                        "name": "role",
                        "updateDate": None,
                        "value": "searchbox"
                    },
                    {
                        "name": "aria-autocomplete",
                        "updateDate": None,
                        "value": "list"
                    },
                    {
                        "name": "aria-controls",
                        "updateDate": None,
                        "value": "sac-autocomplete-results-container"
                    },
                    {
                        "name": "aria-expanded",
                        "updateDate": None,
                        "value": "true"
                    },
                    {
                        "name": "aria-haspopup",
                        "updateDate": None,
                        "value": "grid"
                    },
                    {
                        "name": "spellcheck",
                        "updateDate": None,
                        "value": "false"
                    },
                    {
                        "name": "browser-user-highlight-id",
                        "updateDate": None,
                        "value": "playwright-highlight-2"
                    }
                ],
                "baseURI": "https://www.amazon.com/",
                "className": "nav-input nav-progressive-attribute",
                "id": "twotabsearchtextbox",
                "innerText": "",
                "locationHref": "https://www.amazon.com/",
                "mode": "static",
                "name": "Search Amazon",
                "pageTitle": "Amazon.com. Spend less. Smile more.",
                "selector": [
                    {
                        "key": "id",
                        "value": [
                            {
                                "key": "id",
                                "value": "twotabsearchtextbox"
                            }
                        ],
                        "viewkey": "Id"
                    },
                    {
                        "key": "name",
                        "value": [
                            {
                                "key": "name",
                                "value": "field-keywords"
                            }
                        ],
                        "viewkey": "name"
                    },
                    {
                        "key": "xpath",
                        "value": [
                            {
                                "key": "xpath by combination",
                                "value": "//INPUT[normalize-space(@id)=\"twotabsearchtextbox\"]"
                            }
                        ],
                        "viewkey": "xpath"
                    },
                    {
                        "key": "xpath",
                        "value": [
                            {
                                "key": "xpath by combination regex",
                                "value": "//*[normalize-space(@id)=\"twotabsearchtextbox\"]"
                            }
                        ],
                        "viewkey": "xpath"
                    }
                ],
                "sourceCode": "<input type=\"text\" id=\"twotabsearchtextbox\" value=\"\" name=\"field-keywords\" autocomplete=\"off\" placeholder=\"Search Amazon\" class=\"nav-input nav-progressive-attribute\" dir=\"auto\" tabindex=\"0\" aria-label=\"Search Amazon\" role=\"searchbox\" aria-autocomplete=\"list\" aria-controls=\"sac-autocomplete-results-container\" aria-expanded=\"true\" aria-haspopup=\"grid\" spellcheck=\"false\" browser-user-highlight-id=\"playwright-highlight-2\">",
                "tagName": "INPUT",
                "type": "textfield",
                "uuid": "3ccecc24-cceb-a045-d7ad-74c2f3e145eb"
            },
            "input": "t shirt",
            "nlpName": "SendKeys"
        },
        {
            "aiReferenceElement": "JSHandle@<input value=\"Go\" tabindex=\"0\" type=\"submit\" id=\"nav-search-submit-button\" class=\"nav-input nav-progressive-attribute\" browser-user-highlight-id=\"playwright-highlight-3\"/>",
            "element": {
                "PopupCoordinatesArr": {
                    "clickX": 838,
                    "clickY": 30,
                    "scrollX": 0,
                    "scrollY": 0,
                    "winInnerHeight": 1100,
                    "winInnerWidth": 1280
                },
                "absoluteXpath": "/HTML/BODY/DIV[1]/HEADER/DIV/DIV[1]/DIV[2]/DIV/FORM/DIV[3]/DIV/SPAN/INPUT",
                "attributes": [
                    {
                        "name": "id",
                        "updateDate": None,
                        "value": "nav-search-submit-button"
                    },
                    {
                        "name": "type",
                        "updateDate": None,
                        "value": "submit"
                    },
                    {
                        "name": "class",
                        "updateDate": None,
                        "value": "nav-input nav-progressive-attribute"
                    },
                    {
                        "name": "value",
                        "updateDate": None,
                        "value": "Go"
                    },
                    {
                        "name": "tabindex",
                        "updateDate": None,
                        "value": "0"
                    },
                    {
                        "name": "browser-user-highlight-id",
                        "updateDate": None,
                        "value": "playwright-highlight-3"
                    }
                ],
                "baseURI": "https://www.amazon.com/",
                "className": "nav-input nav-progressive-attribute",
                "id": "nav-search-submit-button",
                "innerText": "",
                "locationHref": "https://www.amazon.com/",
                "mode": "static",
                "name": "Go",
                "pageTitle": "Amazon.com. Spend less. Smile more.",
                "selector": [
                    {
                        "key": "id",
                        "value": [
                            {
                                "key": "id",
                                "value": "nav-search-submit-button"
                            }
                        ],
                        "viewkey": "Id"
                    },
                    {
                        "key": "xpath",
                        "value": [
                            {
                                "key": "xpath by combination",
                                "value": "//INPUT[normalize-space(@id)=\"nav-search-submit-button\"]"
                            }
                        ],
                        "viewkey": "xpath"
                    },
                    {
                        "key": "xpath",
                        "value": [
                            {
                                "key": "xpath by combination regex",
                                "value": "//*[normalize-space(@id)=\"nav-search-submit-button\"]"
                            }
                        ],
                        "viewkey": "xpath"
                    }
                ],
                "sourceCode": "<input id=\"nav-search-submit-button\" type=\"submit\" class=\"nav-input nav-progressive-attribute\" value=\"Go\" tabindex=\"0\" browser-user-highlight-id=\"playwright-highlight-3\">",
                "tagName": "INPUT",
                "type": "button",
                "uuid": "daceb6b0-3965-5748-0303-d3e0eb976bab"
            },
            "input": "",
            "nlpName": "Click"
        }
    ]

# %%
import uuid

class ElementProcessor:
    def __init__(self):
        pass

    def process_elements(self, data):
        for output in data:
            element_dict = {}
            elementname = None
            locators = []
            
            # If "element" doesn't exist in the output, skip the current iteration
            if not output.get("element"):
                continue

            # Process each selector inside the "element"
            for selector in output.get("element").get("selector"):
                locator = {
                    "value": selector.get("value")[0].get("value"),
                    "type": "static",
                    "name": selector.get("value")[0].get("key"),
                    "status": "NOT_USED",
                    "isRecorded": "N",
                    "priority": "",
                    "defaultAddedFirst": False,
                    "defaultAddedSecond": False
                }
                if str(selector.get("value")[0].get("key")).lower() == 'name':
                    elementname = selector.get("value")[0].get("value")
                
                locators.append(locator)
            if elementname is None:
                elementname = f"ELE{uuid.uuid4()}"
            element_dict["locators"] = locators
            element_dict["elementName"] = elementname
            self.element_save(element_dict)

    def element_save(self, element_dict: dict):
        uniq_id = uuid.uuid4()
        json = {
            "_id": uniq_id,
            "executionOrder": 1,
            "hierarchy": 0,
            "name": element_dict.get("elementName"),
            "desc": "",
            "type": element_dict.get("type", ""),
            "locatorsCount": len(element_dict.get("locators")),
            "locators": element_dict.get("locators"),
            "isShared": "N",
            "isRecorded": "Y",
            "folder": False,
            "platform": "Web",
            "projectType": "Web",
            "projectId": element_dict.get("projectId", ""),
            "elementId": uniq_id,
            "users": [""],
            "excludeUsers": [],
            "deleteUsers": [],
            "activeStatus": True,
            "updatedStatus": True,
            "imported": True,
            "createdBy": element_dict.get("createdBy", ""),
            "modifiedBy": element_dict.get("modifiedBy", ""),
            "createdByUname": element_dict.get("createdByUname", ""),
            "modifiedByUname": element_dict.get("modifiedByUname", ""),
            "createdOn": element_dict.get("createdOn", ""),
            "modifiedOn": element_dict.get("modifiedOn", ""),
            "state": "APPROVED",
            "path": element_dict.get("path", ""),
            "searchKey": element_dict.get("searchKey", ""),
            "parentId": element_dict.get("parentId", ""),
            "parentName": element_dict.get("parentName", ""),
            "version": "1.0",
        }
        print(json)
# Out:
# field-keywords
# ELE32a5cc05-39df-4281-9d2a-7feb36cb1762

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://fire:fire123@103.182.210.226:27017,103.182.210.226:27018,103.182.210.226:27019/?authMechanism=DEFAULT&authSource=admin&tls=true&tlsCAFile=C%3A%5CUsers%5CUser%5CDownloads%5CrootCA.pem&tlsCertificateKeyFile=C%3A%5CUsers%5CUser%5CDownloads%5Cmongodb.pem&tlsInsecure=true")

# %%
client["optimize_dev2_LIC3938"]["aiElement"].find_one({"_id":""})
# Out:
# Collection(Database(MongoClient(host=['103.182.210.226:27019', '103.182.210.226:27017', '103.182.210.226:27018'], document_class=dict, tz_aware=False, connect=True, authmechanism='DEFAULT', authsource='admin', tls=True, tlscafile='C:\\Users\\User\\Downloads\\rootCA.pem', tlscertificatekeyfile='C:\\Users\\User\\Downloads\\mongodb.pem', tlsinsecure=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True, tlsallowinvalidhostnames=True), 'optimize_dev2_LIC3938'), 'aiElement')

# %%
locators
# Out:
# [{'value': 'nav-search-submit-button',
#   'type': 'static',
#   'name': 'id',
#   'status': 'NOT_USED',
#   'isRecorded': 'N',
#   'priority': '',
#   'defaultAddedFirst': False,
#   'defaultAddedSecond': False},
#  {'value': '//INPUT[normalize-space(@id)="nav-search-submit-button"]',
#   'type': 'static',
#   'name': 'xpath by combination',
#   'status': 'NOT_USED',
#   'isRecorded': 'N',
#   'priority': '',
#   'defaultAddedFirst': False,
#   'defaultAddedSecond': False},
#  {'value': '//*[normalize-space(@id)="nav-search-submit-button"]',
#   'type': 'static',
#   'name': 'xpath by combination regex',
#   'status': 'NOT_USED',
#   'isRecorded': 'N',
#   'priority': '',
#   'defaultAddedFirst': False,
#   'defaultAddedSecond': False}]
